# %% [markdown]
# ## **Overview**
# **we will explore how to develop a suite of different types of LSTM models for time series forecasting.**
#
# * ### **Univariate LSTM Models**
#
# 1. Data Preparation
# 2. Vanilla LSTM
# 3. Stacked LSTM
# 4. Bidirectional LSTM
# 5. CNN LSTM
# 6. ConvLSTM
#
#
# * ### **Multivariate LSTM Models**
#
# * ### **Multi-Step LSTM Models**
#
# * ### **Multivariate Multi-Step LSTM Models**

# %%
import matplotlib
import warnings
# 忽略警告
warnings.filterwarnings("ignore", category=matplotlib.MatplotlibDeprecationWarning)
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score as r2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from keras.wrappers.scikit_learn import KerasRegressor
# from scikeras.wrappers import KerasRegressor # 回归神经网络
from numpy import array
from keras.models import Sequential
from keras.layers import TimeDistributed
from keras.layers import Dense
from keras.layers import MaxPooling1D, Conv1D,Flatten
# univariate bidirectional lstm example
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from tensorflow.python.keras.layers import CuDNNLSTM
from keras.layers import Bidirectional
import keras.backend as K
import os
import glob
import tensorflow as tf
from tensorflow.python.keras.layers import Activation
from keras import optimizers
from pygame import mixer
import time
import time
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import r2_score as r2

# %%
def read_someone_day_file(day):
    IMF = []
    xlsx_file = '../../Data/CEEMDAN/58606_2/'+day+'/'
    xlsx_path = glob.glob(os.path.join(xlsx_file,'*.xlsx'))

    data_col_len = pd.read_excel('../../Data/CEEMDAN/58606_2/'+day+'/CEEMDAN_58606 Station_g.xlsx',header=None)

    for imf_len in range(len(data_col_len.columns)):
        for file in xlsx_path:
             print(file)
             # print(os.path.basename(file))
             imfs = pd.read_excel(file,header=None)
             imfn = imfs.iloc[:,imf_len]
             imfn.to_numpy()
             IMF.append(imfn )
        print(imf_len,"-------------------")
    return IMF

# %%
def Result_Ana(Model, feature_num,testX,testY,scaler):
    print('Result_Ana_Function:',testX.shape)
    y_pred = Model.predict(testX)
    y_pred = np.array(y_pred).reshape(-1, 1)
    # 将一个数组prediction在最后一个轴上（即axis=-1）进行复制，重复8次，并将结果存储在prediction_copies_array数组中
    prediction_copies_array = np.repeat(y_pred, feature_num,axis=-1)
    prediction_copies_array
    print('-----------prediction copy Shape：',prediction_copies_array.shape,'------------------')
    # Multi Var prediction
    pred = scaler.inverse_transform(np.reshape(prediction_copies_array, (len(y_pred), feature_num)))[:,feature_num-1] #进行逆变换但是，只需要最后一列
    # Single prediction
    # pred = scaler.inverse_transform(y_pred) #进行逆变换但是，只需要最后一列

    # print(pred)
    print('testY of shape :',testY.shape)
    y_true = np.array(testY).reshape(-1, 1)
    original_copies_array = np.repeat(testY, feature_num, axis=-1)
    print('IMF_True:',scaler.inverse_transform(np.reshape(original_copies_array, (len(testY), feature_num))))
    y_true = scaler.inverse_transform(np.reshape(original_copies_array, (len(testY), feature_num)))[:, feature_num-1]

    print('feature_num-1_ETO_true:',y_true)

    # Single true value
    # y_true = scaler.inverse_transform(np.array(testY).reshape(-1,1))

    # y_true
    # pred

    print(pred)
    plt.plot(y_true, color='red', label='Real Value')
    plt.plot(pred, color='blue', label='Pred Value')
    plt.title('Prediction ETO (mm)')
    plt.xlabel('Time (day)')
    plt.ylabel('ETO (mm)')
    plt.legend()
    plt.show()


    print('MSE:',mse(y_true,pred))
    print('MAE:',mae(y_true,pred))
    print('R²:',r2(y_true,pred))
    print('RMSE:',np.sqrt(mse(y_true,pred)))
    print('pred_finally:',pred)

    return y_true,pred

# %%
def ceemdan_lstm(day):
    mixer.init()
    mixer.music.load('../../Resources/ExecuteTipAudio.mp3')

    reshape1 = 0
    IMF = read_someone_day_file(day)

    imf_choose = 0
    finally_rsult = []
    finally_y_true = []

    for imf_run in range(int(len(IMF) / 7)):
        ALL_Factor_IMF = IMF[imf_choose:imf_choose+7][:]
        imf_choose = imf_choose + 7

        print('--------------------------',imf_run,'--------------------------')
        ALL_Factor_IMF = np.array(ALL_Factor_IMF)
        IMF_Input = np.transpose(ALL_Factor_IMF)

        df_IMF = pd.DataFrame(IMF_Input)
        df_IMF.columns = ['one','two','three','four','five','six', 'seven']

        print(df_IMF)

        scaler = MinMaxScaler(feature_range=(0, 1))
        df = scaler.fit_transform(df_IMF)

        sacler_data_len = len(df_IMF.columns)

        #数据集划分
        test_split = round(len(df) * 0.20)
        print(test_split)
        def splitData(var, per_test):
            num_test = int(len(var) * per_test)
            train_size = int(len(var) - num_test)
            train_data = var[0:train_size]
            test_data = var[train_size:train_size + num_test]
            return train_data, test_data


        df_training, df_testing = splitData(df, 0.2)
        print('df_training.shape:',df_training.shape)
        print('df_testing.shape:',df_testing.shape)

        def createXY(data,n_past,n_steps_out):
            dataX,dataY = list(),list()

            for i in range(len(data)):
                ## such as: len(data) = 19624
                end_ix = i + n_past ## 0+3=3,1+3=4,...,19618+3=19621
                out_end_ix = end_ix + n_steps_out ## 3+3=6,4+3=7,...,19621+3=19624
                # print('out_end_ix:',out_end_ix)
                '''
                加入此处判断，使得最终的dataX和dataY中每行的数组长度一致，进而可以转换为array(数组),如若不加以限制，
                则导致最后几次循环由于i是在len(data)范围内的，
                但是由于out_end_ix=end_ix + n_steps_out,最终会超出data的数据范围，而导致其无法获取到数据,
                加入dataY之后，最后几行的数据长度是和前面的数据长度不一致，最终导致无法进行array转换
                '''
                if out_end_ix > len(data): ## 6 < len(data),7<len(data),...,19623+3=19626>len(data)=19624
                    # print("------------out_end_ix of end",out_end_ix,'---------------')
                    break

                dataX.append(data[i:end_ix,0:data.shape[1]]) ## 0:3,0:7;1:4,0:7
                dataY.append(data[end_ix:out_end_ix,data.shape[1]-1]) ##3:6,6;4:7,6
            return np.array(dataX), np.array(dataY)

        n_past=1
        n_steps_out=1

        trainX, trainY = createXY(df_training, n_past, n_steps_out)
        testX, testY = createXY(df_testing, n_past, n_steps_out)

        reshape1 = testY.shape[0]

        print('trainX.Shape:----', trainX.shape)
        print('trainY.shape:----', trainY.shape)
        print('testX.shape:----', testX.shape)
        print('testY.shape:----', testY.shape)

        trainY = trainY.reshape(-1)
        testY = testY.reshape(-1)
        print('trainY Shape 2 ---', trainY.shape)
        print('testY Shape 2 ---', testY.shape)
        trainX = np.expand_dims(trainX,axis=1)
        testX = np.expand_dims(testX,axis=1)
        print('expand_dims_trainX of shape',trainX.shape)
        print('expand_dims_testX of shape',testX.shape)

        print('----------------------------',imf_run,'------------------------------')

        def CNNLSTM(optimizer='adam', batch_size=32, epochs=40):

            model = Sequential()
            # Modify kernel_size=1 can execute?
            model.add(TimeDistributed(Conv1D(filters=256, kernel_size=1, activation='relu', input_shape=(None, 1, sacler_data_len),padding='same')))
            model.add(TimeDistributed(Conv1D(filters=256, kernel_size=1, activation='relu')))
            model.add(TimeDistributed(Dropout(0.1)))
            model.add(TimeDistributed(MaxPooling1D(pool_size=1)))
            model.add(TimeDistributed(Flatten()))
            model.add(Dense(100, activation='relu'))
            model.add(LSTM(100, activation='relu'))
            model.add(Dropout(0.1))
            model.add(Dense(1))
            # model.add(Activation('linear'))
            model.compile(optimizer=optimizer, loss='mse', metrics='accuracy')
            return model

        BiLSTM_Model = KerasRegressor(CNNLSTM, epochs=40, verbose=1, validation_data=(testX, testY))
        # N_LSTM_Model = KerasRegressor(N_LSTM, epochs=40, verbose=1)

        from sklearn.model_selection import GridSearchCV

        # 定义超参数搜索范围
        param_grid = {
            'optimizer': ['Adam'],
            'batch_size': [32, 64],
            'epochs': [20, 30]
            # 'batch_size': [64],
            # 'epochs': [40]
        }

        # 执行网格搜索
        grid = GridSearchCV(estimator=BiLSTM_Model, param_grid=param_grid, cv=2)
        grid_result = grid.fit(trainX, trainY)

        best_params = grid_result.best_params_

        best_params
        print('prediction' , 'one' ,'day best_params:', best_params)

        best_model = grid_result.best_estimator_

        y_trues,prediction_result = Result_Ana(best_model, sacler_data_len,testX,testY,scaler)

        print('prediction_result:',prediction_result)
        finally_rsult.append(prediction_result)
        print('lstm_y_turs:',y_trues)
        finally_y_true.append(y_trues)

        mixer.music.play()
        time.sleep(1)
        mixer.music.stop()
    return reshape1,finally_y_true,finally_rsult,day

# %%
def plot_save_true_prediction(reshape1,finally_y_true,finally_rsult,day):
    # WL(Water Level(m)) For IMF1-IMF13-R True Value
    finally_y_true
    finally_ytrue_r = np.array(finally_y_true)
    finally_ytrue_r
    reshape2 = len(finally_ytrue_r)
    reshape2
    finally_column_names = []

    for i in range(1, reshape2 + 1):
        if i < (reshape2):
            finally_column_names.append("IMF" + str(i))
        else:
            finally_column_names.append("Residual")
    finally_column_names
    ALL_Factor_ReIMFS_Yture_Result = np.transpose(finally_ytrue_r)
    reshape1
    ALL_Factor_ReIMFS_Yture_Result = ALL_Factor_ReIMFS_Yture_Result.reshape(reshape1, reshape2)
    all_factor_ceemdan_true = pd.DataFrame(ALL_Factor_ReIMFS_Yture_Result, columns=finally_column_names)
    all_factor_ceemdan_true
    sums = all_factor_ceemdan_true.iloc[:, :].sum(axis=1)

    # 将求和结果添加到DataFrame中作为新的一列
    all_factor_ceemdan_true["True"] = sums
    # 保存为CSV文件
    true_file_path = "Result/CEEMDAN/"+day+"_day_CEEMDAN_IMF" + str(reshape2 - 1) + "-CNN_true.csv"

    all_factor_ceemdan_true.to_csv(true_file_path,
                                   index=False)
    # WL(Water Level(m)) IMF1-IMF13-R Prediction Value
    finally_rsult
    finally_r = np.array(finally_rsult)
    finally_r
    ALL_Factor_ReIMFS_Result = np.transpose(finally_r)
    ALL_Factor_ReIMFS_Result = ALL_Factor_ReIMFS_Result.reshape(reshape1, reshape2)
    finally_column_names
    all_factor_ceemdan_prediction = pd.DataFrame(ALL_Factor_ReIMFS_Result, columns=finally_column_names)
    all_factor_ceemdan_prediction
    sums = all_factor_ceemdan_prediction.iloc[:, :].sum(axis=1)

    # 将求和结果添加到DataFrame中作为新的一列
    all_factor_ceemdan_prediction["Pred"] = sums
    prediction_file_path = "Result/CEEMDAN/"+day+"_day_CEEMDAN_IMF" + str(reshape2 - 1) + "-CNN_prediction.csv"
    # 保存为CSV文件
    all_factor_ceemdan_prediction.to_csv(prediction_file_path, index=False)
    ### 验证最终结果
    df = pd.read_csv(prediction_file_path)
    df = df[['Pred']]
    df

    origin = pd.read_csv(true_file_path)
    origin = origin[['True']]
    # y_true = origin.iloc[:,len(origin.columns)-1]
    y_true = origin
    y_true
    pred = df
    y_true
    pred
    plt.plot(y_true, color='red', label='Real Value')
    plt.plot(pred, color='blue', label='Pred Value')
    plt.title('Prediction ET0 ')
    plt.xlabel('Time')
    plt.ylabel('Detail Value')
    plt.legend()
    # plt.savefig('../Images/SW_IN_F_Train_'+'n_past='+'{}'.format((trainX[1].shape)[0])+'_epochs={}'.format((grid_search.best_params_)['epochs'])+'.png',dpi=600)
    plt.show()
    # y_true_data = pd.DataFrame(y)
    # y_true_data.to_csv('../ResultAnaAndProcess/Result/All Features/RF/37390_300/' + 'RF_{}'.format(site_name) + '_True' + '.csv',
    #               index=False)
    # pred_data = pd.DataFrame(pred)
    # pred_data.to_csv('../ResultAnaAndProcess/Result/All Features/RF/37390_300/' + 'RF_{}'.format(site_name) + '_Pre' + '.csv',
    #              index=False)
    from sklearn.metrics import mean_squared_error as mse
    from sklearn.metrics import mean_absolute_error as mae
    from sklearn.metrics import r2_score as r2

    print('MSE:', mse(y_true, pred))
    print('MAE:', mae(y_true, pred))
    print('R²:', r2(y_true, pred))
    print('RMSE:', np.sqrt(mse(y_true, pred)))
    print('pred_finally:', pred)

# %%
# %%time
if __name__ == '__main__':
    days = ['OneDay','ThreeDay','FiveDay','FifteenDay']
    for day in days:
       print('------------------',day ,'--------------------')
       print('This is ',day,'-th for prediction et0')
       reshape1,finally_y_true,finally_rsult,day = ceemdan_lstm(day)
       print('This is ',day,'-th for prediction et0')
       print('------------------',day,'---------------------')
       plot_save_true_prediction(reshape1,finally_y_true,finally_rsult,day)
# Out:
# ------------------ OneDay --------------------
# This is  OneDay -th for prediction et0
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 0 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 1 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 2 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 3 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 4 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 5 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 6 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 7 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 8 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 9 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 10 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 11 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 12 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 13 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 14 -------------------
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_a.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_b.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_c.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_d.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_e.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_f.xlsx
# ../../Data/CEEMDAN/58606_2/OneDay\CEEMDAN_58606 Station_g.xlsx
# 15 -------------------
# -------------------------- 0 --------------------------
#             one       two     three      four      five            six  \
# 0     -1.464790 -0.919115 -0.454365 -0.700750  4.012725     685.750749
# 1      0.602649  1.217254  0.396571 -0.935308  1.183604    -813.232746
# 2      1.359043  1.732350 -1.770660  1.522547 -3.100436    -640.572992
# 3      0.450546 -0.091290  1.786784  1.385560  3.499083     544.515857
# 4     -1.818005 -0.277202 -1.002048 -0.330014 -3.927123    -225.735636
# ...         ...       ...       ...       ...       ...            ...
# 24525 -1.318127 -0.733819 -0.614148  0.475756  2.895771 -352873.241491
# 24526 -0.154782 -0.111291 -0.659385 -0.358708 -0.420595  436446.198249
# 24527  0.122398 -0.078915  0.883395  0.054605 -0.756205 -513694.896792
# 24528  0.550918  0.530208 -0.437380 -0.031215  1.639937  544410.537922
# 24529  0.561766  0.728185  1.188857  0.095620 -2.894580 -450402.121704
#
#           seven
# 0     -0.363139
# 1     -0.151901
# 2      0.255424
# 3      0.067973
# 4     -0.013659
# ...         ...
# 24525 -0.251898
# 24526 -0.296357
# 24527  0.226946
# 24528 -0.039735
# 24529  0.431384
#
# [24530 rows x 7 columns]
# 4906
# df_training.shape: (19624, 7)
# df_testing.shape: (4906, 7)
# trainX.Shape:---- (19623, 1, 7)
# trainY.shape:---- (19623, 1)
# testX.shape:---- (4905, 1, 7)
# testY.shape:---- (4905, 1)
# trainY Shape 2 --- (19623,)
# testY Shape 2 --- (4905,)
# expand_dims_trainX of shape (19623, 1, 1, 7)
# expand_dims_testX of shape (4905, 1, 1, 7)
# ---------------------------- 0 ------------------------------
# Epoch 1/20
# C:\Users\AnleHrc\AppData\Local\Temp\ipykernel_75124\3524855001.py:108: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   BiLSTM_Model = KerasRegressor(CNNLSTM, epochs=40, verbose=1, validation_data=(testX, testY))
# 307/307 [==============================] - 3s 4ms/step - loss: 0.0163 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 2.0387e-04
# Epoch 2/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 3/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 5/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 6/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0125 - val_accuracy: 2.0387e-04
# Epoch 7/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 8/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 9/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 10/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 11/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 12/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 13/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 14/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 15/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 16/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 17/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 18/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 19/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 20/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# 307/307 [==============================] - 0s 974us/step - loss: 0.0113 - accuracy: 0.0000e+00
# Epoch 1/20
# 307/307 [==============================] - 2s 4ms/step - loss: 0.0185 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0126 - accuracy: 0.0000e+00 - val_loss: 0.0142 - val_accuracy: 2.0387e-04
# Epoch 3/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0123 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 4/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 5/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 2.0387e-04
# Epoch 6/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 2.0387e-04
# Epoch 7/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0119 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 8/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 9/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 10/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 12/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 13/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 2.0387e-04
# Epoch 14/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 15/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 2.0387e-04
# Epoch 16/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 17/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 18/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 19/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 2.0387e-04
# Epoch 20/20
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# 307/307 [==============================] - 0s 869us/step - loss: 0.0102 - accuracy: 0.0000e+00
# Epoch 1/30
# 307/307 [==============================] - 2s 4ms/step - loss: 0.0171 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 4/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 5/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 6/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 7/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 8/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 9/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 10/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 11/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 12/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 13/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 14/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 15/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 16/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 17/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 2.0387e-04
# Epoch 18/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 19/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 4.0775e-04
# Epoch 20/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 2.0387e-04
# Epoch 21/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 22/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 23/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 24/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 4.0775e-04
# Epoch 25/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 4.0775e-04
# Epoch 26/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 4.0775e-04
# Epoch 27/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 2.0387e-04
# Epoch 28/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 4.0775e-04
# Epoch 29/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 4.0775e-04
# Epoch 30/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 4.0775e-04
# 307/307 [==============================] - 0s 840us/step - loss: 0.0113 - accuracy: 0.0000e+00
# Epoch 1/30
# 307/307 [==============================] - 2s 3ms/step - loss: 0.0177 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0126 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 3/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0124 - accuracy: 0.0000e+00 - val_loss: 0.0125 - val_accuracy: 2.0387e-04
# Epoch 4/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 6/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 7/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 8/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 9/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 10/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 11/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 13/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 14/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 15/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 16/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 17/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 18/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 19/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 20/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 21/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 22/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 2.0387e-04
# Epoch 23/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 24/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 25/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 26/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 27/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 28/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 29/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 30/30
# 307/307 [==============================] - 1s 3ms/step - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# 307/307 [==============================] - 0s 808us/step - loss: 0.0098 - accuracy: 0.0000e+00
# Epoch 1/20
# 154/154 [==============================] - 2s 5ms/step - loss: 0.0204 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0130 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 2.0387e-04
# Epoch 4/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 6/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 7/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 2.0387e-04
# Epoch 8/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 9/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 10/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 11/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 2.0387e-04
# Epoch 12/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 13/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 14/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 15/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 16/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 17/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 18/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 2.0387e-04
# Epoch 19/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 20/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0112 - accuracy: 0.0000e+00
# Epoch 1/20
# 154/154 [==============================] - 2s 5ms/step - loss: 0.0230 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0128 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0126 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 2.0387e-04
# Epoch 4/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0123 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0122 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 9/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.0121 - val_accuracy: 2.0387e-04
# Epoch 10/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 11/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0119 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 12/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0119 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 14/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 15/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 16/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 17/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 18/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 19/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 20/20
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# 154/154 [==============================] - 0s 993us/step - loss: 0.0100 - accuracy: 0.0000e+00
# Epoch 1/30
# 154/154 [==============================] - 2s 5ms/step - loss: 0.0244 - accuracy: 0.0000e+00 - val_loss: 0.0125 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0125 - val_accuracy: 2.0387e-04
# Epoch 3/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 4/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 2.0387e-04
# Epoch 5/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 6/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 7/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 8/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 9/30
# 154/154 [==============================] - 1s 4ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 2.0387e-04
# Epoch 10/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 11/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 12/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 13/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 14/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 15/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 16/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 17/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 18/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 19/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 20/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 21/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 22/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 23/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 24/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 2.0387e-04
# Epoch 25/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 26/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0101 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 27/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 28/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 29/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 30/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 2.0387e-04
# 154/154 [==============================] - 0s 919us/step - loss: 0.0114 - accuracy: 0.0000e+00
# Epoch 1/30
# 154/154 [==============================] - 2s 5ms/step - loss: 0.0231 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0127 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0126 - accuracy: 0.0000e+00 - val_loss: 0.0128 - val_accuracy: 2.0387e-04
# Epoch 4/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 2.0387e-04
# Epoch 5/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0119 - val_accuracy: 2.0387e-04
# Epoch 6/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0120 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 9/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0119 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 2.0387e-04
# Epoch 10/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0119 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 11/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 2.0387e-04
# Epoch 12/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 13/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 14/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0119 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 16/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 17/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 18/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 19/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 20/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 21/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 22/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 23/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 24/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 25/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 26/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 27/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 28/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 2.0387e-04
# Epoch 29/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 30/30
# 154/154 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# 154/154 [==============================] - 0s 902us/step - loss: 0.0098 - accuracy: 0.0000e+00
# Epoch 1/30
# 614/614 [==============================] - 3s 3ms/step - loss: 0.0146 - accuracy: 0.0000e+00 - val_loss: 0.0122 - val_accuracy: 2.0387e-04
# Epoch 2/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0130 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 4/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0113 - accuracy: 0.0000e+00 - val_loss: 0.0118 - val_accuracy: 2.0387e-04
# Epoch 5/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0112 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 7/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0109 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 8/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 2.0387e-04
# Epoch 9/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 2.0387e-04
# Epoch 10/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0114 - val_accuracy: 2.0387e-04
# Epoch 11/30
# 614/614 [==============================] - 2s 3ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 12/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 13/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 14/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 15/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0106 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 16/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 2.0387e-04
# Epoch 17/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 18/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 19/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 20/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 2.0387e-04
# Epoch 21/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 2.0387e-04
# Epoch 22/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 4.0775e-04
# Epoch 23/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 24/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 4.0775e-04
# Epoch 25/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 4.0775e-04
# Epoch 26/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 2.0387e-04
# Epoch 27/30
# 614/614 [==============================] - 2s 3ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0115 - val_accuracy: 2.0387e-04
# Epoch 28/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0104 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 4.0775e-04
# Epoch 29/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 2.0387e-04
# Epoch 30/30
# 614/614 [==============================] - 2s 2ms/step - loss: 0.0103 - accuracy: 0.0000e+00 - val_loss: 0.0111 - val_accuracy: 4.0775e-04
# prediction one day best_params: {'batch_size': 32, 'epochs': 30, 'optimizer': 'Adam'}
# Result_Ana_Function: (4905, 1, 1, 7)
# 154/154 [==============================] - 0s 739us/step
# -----------prediction copy Shape： (4905, 7) ------------------
# testY of shape : (4905,)
# IMF_True: [[-1.62177792e+00 -9.91463976e-01 -9.50939915e-01 ... -4.60865959e+00
#   -7.88576478e+04 -2.28466688e-01]
#  [-3.94502215e+00 -2.61938931e+00 -3.00044805e+00 ... -1.27078244e+01
#   -2.32399341e+05 -9.19406101e-01]
#  [ 7.28175856e-01  6.55177062e-01  1.12213072e+00 ...  3.58361857e+00
#    7.64492620e+04  4.70416220e-01]
#  ...
#  [-9.04779089e-02  8.15364666e-02  3.99934780e-01 ...  7.29673350e-01
#    2.23449696e+04  2.26946272e-01]
#  [-9.87178223e-01 -5.46792290e-01 -3.91111881e-01 ... -2.39635341e+00
#   -3.69173683e+04 -3.97349403e-02]
#  [ 5.96931678e-01  5.63212679e-01  1.00635038e+00 ...  3.12608242e+00
#    6.77754201e+04  4.31383830e-01]]
# feature_num-1_ETO_true: [-0.22846669 -0.9194061   0.47041622 ...  0.22694627 -0.03973494
#   0.43138383]
# [-0.5600193   0.0104985   0.21473448 ...  0.12251999 -0.2873202
#   0.14274918]
# MSE: 0.25116332840281036
# MAE: 0.36177690526159145
# R²: 0.0897019788834138
# RMSE: 0.5011619782094511
# pred_finally: [-0.5600193   0.0104985   0.21473448 ...  0.12251999 -0.2873202
#   0.14274918]
# prediction_result: [-0.5600193   0.0104985   0.21473448 ...  0.12251999 -0.2873202
#   0.14274918]
# lstm_y_turs: [-0.22846669 -0.9194061   0.47041622 ...  0.22694627 -0.03973494
#   0.43138383]
# -------------------------- 1 --------------------------
#             one       two     three      four      five            six  \
# 0     -0.717649 -0.700243 -1.302272  1.167898  2.246833    -266.541681
# 1     -0.067041  0.133359 -1.809280  1.549877  0.945760    -702.111248
# 2      0.406846  0.474059 -0.593264  1.616759  0.143621    -308.938576
# 3      0.233040  0.235515  1.043773  1.200236 -0.919376     127.959321
# 4     -0.127228 -0.141003  1.191214  0.368845 -0.945895      63.058347
# ...         ...       ...       ...       ...       ...            ...
# 24525  0.130000  0.020085 -0.993216  0.027438 -0.011930  219111.062916
# 24526 -0.156846 -0.052118 -0.313668  0.006436  0.185257  395650.314402
# 24527 -0.160471 -0.074216  0.445951 -0.041243  0.264299  303018.619420
# 24528  0.320849  0.065932  1.350096 -0.012000 -0.618084  212944.636586
# 24529  0.650434  0.393185  2.284899  0.067460 -2.319555  204257.945214
#
#           seven
# 0     -0.186260
# 1     -0.053783
# 2      0.020862
# 3      0.051265
# 4      0.003498
# ...         ...
# 24525 -0.127204
# 24526 -0.027485
# 24527  0.082941
# 24528  0.297979
# 24529  0.577462
#
# [24530 rows x 7 columns]
# 4906
# df_training.shape: (19624, 7)
# df_testing.shape: (4906, 7)
# trainX.Shape:---- (19623, 1, 7)
# trainY.shape:---- (19623, 1)
# testX.shape:---- (4905, 1, 7)
# testY.shape:---- (4905, 1)
# trainY Shape 2 --- (19623,)
# testY Shape 2 --- (4905,)
# expand_dims_trainX of shape (19623, 1, 1, 7)
# expand_dims_testX of shape (4905, 1, 1, 7)
# ---------------------------- 1 ------------------------------
# Epoch 1/20
# ...
# 154/154 [==============================] - 1s 5ms/step - loss: 5.0627e-04 - accuracy: 1.0192e-04 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 154/154 [==============================] - 1s 5ms/step - loss: 4.3280e-04 - accuracy: 1.0192e-04 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# 154/154 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 0.0000e+00
# Epoch 1/20
# 307/307 [==============================] - 3s 6ms/step - loss: 0.0146 - accuracy: 5.0961e-05 - val_loss: 3.6541e-04 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0014 - accuracy: 5.0961e-05 - val_loss: 2.8095e-04 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0012 - accuracy: 5.0961e-05 - val_loss: 6.5440e-04 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0012 - accuracy: 5.0961e-05 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0010 - accuracy: 5.0961e-05 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 307/307 [==============================] - 2s 5ms/step - loss: 9.8107e-04 - accuracy: 5.0961e-05 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 307/307 [==============================] - 2s 5ms/step - loss: 8.8991e-04 - accuracy: 5.0961e-05 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 307/307 [==============================] - 2s 5ms/step - loss: 8.6463e-04 - accuracy: 5.0961e-05 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 307/307 [==============================] - 2s 5ms/step - loss: 7.9386e-04 - accuracy: 5.0961e-05 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 307/307 [==============================] - 2s 5ms/step - loss: 7.2925e-04 - accuracy: 5.0961e-05 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 307/307 [==============================] - 1s 5ms/step - loss: 6.5398e-04 - accuracy: 5.0961e-05 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 307/307 [==============================] - 1s 5ms/step - loss: 5.9167e-04 - accuracy: 5.0961e-05 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 307/307 [==============================] - 2s 5ms/step - loss: 5.3427e-04 - accuracy: 5.0961e-05 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 307/307 [==============================] - 2s 5ms/step - loss: 4.9932e-04 - accuracy: 5.0961e-05 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 307/307 [==============================] - 2s 5ms/step - loss: 4.5282e-04 - accuracy: 5.0961e-05 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 307/307 [==============================] - 2s 5ms/step - loss: 4.0345e-04 - accuracy: 5.0961e-05 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 307/307 [==============================] - 2s 5ms/step - loss: 3.8310e-04 - accuracy: 5.0961e-05 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 307/307 [==============================] - 2s 5ms/step - loss: 3.5772e-04 - accuracy: 5.0961e-05 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 307/307 [==============================] - 1s 5ms/step - loss: 3.2896e-04 - accuracy: 5.0961e-05 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 307/307 [==============================] - 1s 5ms/step - loss: 2.9897e-04 - accuracy: 5.0961e-05 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# prediction one day best_params: {'batch_size': 64, 'epochs': 20, 'optimizer': 'Adam'}
# Result_Ana_Function: (4905, 1, 1, 7)
# 77/77 [==============================] - 0s 1ms/step
# -----------prediction copy Shape： (4905, 7) ------------------
# testY of shape : (4905,)
# IMF_True: [[1.67230571e-01 1.48806640e-01 1.14805594e-01 ... 6.54058238e-01
#   2.43503151e+03 3.08156105e-02]
#  [1.66925593e-01 1.48561211e-01 1.14556196e-01 ... 6.52621598e-01
#   2.43117785e+03 3.07324017e-02]
#  [1.66621016e-01 1.48316103e-01 1.14307126e-01 ... 6.51186843e-01
#   2.42732925e+03 3.06493021e-02]
#  ...
#  [1.48871885e-01 1.34032520e-01 9.97926547e-02 ... 5.67576963e-01
#   2.20305330e+03 2.58066992e-02]
#  [1.48787021e-01 1.33964225e-01 9.97232561e-02 ... 5.67177195e-01
#   2.20198096e+03 2.57835450e-02]
#  [1.48701717e-01 1.33895577e-01 9.96534982e-02 ... 5.66775359e-01
#   2.20090307e+03 2.57602711e-02]]
# feature_num-1_ETO_true: [0.03081561 0.0307324  0.0306493  ... 0.0258067  0.02578355 0.02576027]
# [0.02861553 0.02852874 0.02844201 ... 0.0112843  0.01126966 0.01125493]
# MSE: 0.0001387444035336399
# MAE: 0.00926691657726396
# R²: 0.7612302520063619
# RMSE: 0.011778981430227315
# pred_finally: [0.02861553 0.02852874 0.02844201 ... 0.0112843  0.01126966 0.01125493]
# prediction_result: [0.02861553 0.02852874 0.02844201 ... 0.0112843  0.01126966 0.01125493]
# lstm_y_turs: [0.03081561 0.0307324  0.0306493  ... 0.0258067  0.02578355 0.02576027]
# -------------------------- 13 --------------------------
#             one       two     three      four      five          six     seven
# 0     -0.476528 -0.535954  0.058115  0.156373  0.794584  -145.512472 -0.188095
# 1     -0.476607 -0.536039  0.058120  0.156408  0.794350  -145.482358 -0.187964
# 2     -0.476685 -0.536123  0.058125  0.156444  0.794115  -145.452379 -0.187833
# 3     -0.476763 -0.536207  0.058131  0.156480  0.793880  -145.422534 -0.187702
# 4     -0.476840 -0.536291  0.058136  0.156515  0.793644  -145.392825 -0.187571
# ...         ...       ...       ...       ...       ...          ...       ...
# 24525  0.564557  0.217076 -0.287878 -0.122540  2.517826  4483.707294 -0.080850
# 24526  0.564718  0.217074 -0.287934 -0.122488  2.517397  4488.067710 -0.080814
# 24527  0.564879  0.217072 -0.287989 -0.122437  2.516966  4492.426630 -0.080778
# 24528  0.565039  0.217070 -0.288044 -0.122386  2.516536  4496.784050 -0.080742
# 24529  0.565199  0.217067 -0.288099 -0.122335  2.516104  4501.139968 -0.080706
#
# [24530 rows x 7 columns]
# 4906
# df_training.shape: (19624, 7)
# df_testing.shape: (4906, 7)
# trainX.Shape:---- (19623, 1, 7)
# trainY.shape:---- (19623, 1)
# testX.shape:---- (4905, 1, 7)
# testY.shape:---- (4905, 1)
# trainY Shape 2 --- (19623,)
# testY Shape 2 --- (4905,)
# expand_dims_trainX of shape (19623, 1, 1, 7)
# expand_dims_testX of shape (4905, 1, 1, 7)
# ---------------------------- 13 ------------------------------
# Epoch 1/20
# C:\Users\AnleHrc\AppData\Local\Temp\ipykernel_75124\3524855001.py:108: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   BiLSTM_Model = KerasRegressor(CNNLSTM, epochs=40, verbose=1, validation_data=(testX, testY))
# 307/307 [==============================] - 3s 5ms/step - loss: 0.0110 - accuracy: 0.0000e+00 - val_loss: 0.0057 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0050 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 0.0073 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 307/307 [==============================] - 1s 4ms/step - loss: 8.8656e-04 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 307/307 [==============================] - 1s 4ms/step - loss: 8.0429e-04 - accuracy: 0.0000e+00 - val_loss: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 307/307 [==============================] - 1s 4ms/step - loss: 7.5320e-04 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 307/307 [==============================] - 1s 4ms/step - loss: 6.8140e-04 - accuracy: 0.0000e+00 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 307/307 [==============================] - 1s 4ms/step - loss: 6.0589e-04 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 307/307 [==============================] - 1s 4ms/step - loss: 5.2817e-04 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 307/307 [==============================] - 1s 4ms/step - loss: 4.9734e-04 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 307/307 [==============================] - 1s 4ms/step - loss: 4.4766e-04 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 307/307 [==============================] - 1s 4ms/step - loss: 4.2568e-04 - accuracy: 0.0000e+00 - val_loss: 0.0108 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 307/307 [==============================] - 1s 4ms/step - loss: 3.7275e-04 - accuracy: 0.0000e+00 - val_loss: 0.0120 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 307/307 [==============================] - 1s 4ms/step - loss: 3.4039e-04 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 307/307 [==============================] - 1s 4ms/step - loss: 3.3597e-04 - accuracy: 0.0000e+00 - val_loss: 0.0132 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 307/307 [==============================] - 1s 4ms/step - loss: 3.0987e-04 - accuracy: 0.0000e+00 - val_loss: 0.0116 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 307/307 [==============================] - 1s 4ms/step - loss: 2.7802e-04 - accuracy: 0.0000e+00 - val_loss: 0.0123 - val_accuracy: 0.0000e+00
# 307/307 [==============================] - 0s 998us/step - loss: 0.0096 - accuracy: 1.0192e-04
# Epoch 1/20
# 307/307 [==============================] - 3s 4ms/step - loss: 0.0118 - accuracy: 1.0192e-04 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0016 - accuracy: 1.0192e-04 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0014 - accuracy: 1.0192e-04 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 4/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0012 - accuracy: 1.0192e-04 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0013 - accuracy: 1.0192e-04 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 1.0192e-04 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 307/307 [==============================] - 1s 4ms/step - loss: 0.0010 - accuracy: 1.0192e-04 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 8/20
# 307/307 [==============================] - 1s 4ms/step - loss: 8.8763e-04 - accuracy: 1.0192e-04 - val_loss: 0.0028 - val_accuracy: 0.0000e+00
# Epoch 9/20
# 307/307 [==============================] - 1s 4ms/step - loss: 8.4628e-04 - accuracy: 1.0192e-04 - val_loss: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 10/20
# 307/307 [==============================] - 1s 4ms/step - loss: 8.0190e-04 - accuracy: 1.0192e-04 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 11/20
# 307/307 [==============================] - 1s 4ms/step - loss: 6.9607e-04 - accuracy: 1.0192e-04 - val_loss: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 12/20
# 307/307 [==============================] - 1s 4ms/step - loss: 6.7869e-04 - accuracy: 1.0192e-04 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 13/20
# 307/307 [==============================] - 1s 4ms/step - loss: 6.0462e-04 - accuracy: 1.0192e-04 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 14/20
# 307/307 [==============================] - 1s 4ms/step - loss: 5.5638e-04 - accuracy: 1.0192e-04 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 15/20
# 307/307 [==============================] - 1s 4ms/step - loss: 5.2563e-04 - accuracy: 1.0192e-04 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 16/20
# 307/307 [==============================] - 1s 4ms/step - loss: 4.7336e-04 - accuracy: 1.0192e-04 - val_loss: 0.0101 - val_accuracy: 0.0000e+00
# Epoch 17/20
# 307/307 [==============================] - 1s 4ms/step - loss: 4.5096e-04 - accuracy: 1.0192e-04 - val_loss: 0.0071 - val_accuracy: 0.0000e+00
# Epoch 18/20
# 307/307 [==============================] - 1s 4ms/step - loss: 4.2699e-04 - accuracy: 1.0192e-04 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 19/20
# 307/307 [==============================] - 1s 4ms/step - loss: 3.9984e-04 - accuracy: 1.0192e-04 - val_loss: 0.0103 - val_accuracy: 0.0000e+00
# Epoch 20/20
# 307/307 [==============================] - 1s 4ms/step - loss: 3.9554e-04 - accuracy: 1.0192e-04 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# 307/307 [==============================] - 0s 1ms/step - loss: 0.0024 - accuracy: 0.0000e+00
# Epoch 1/30
# 307/307 [==============================] - 3s 6ms/step - loss: 0.0130 - accuracy: 0.0000e+00 - val_loss: 0.0053 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 307/307 [==============================] - 2s 5ms/step - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 307/307 [==============================] - 2s 5ms/step - loss: 9.4767e-04 - accuracy: 0.0000e+00 - val_loss: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 307/307 [==============================] - 2s 5ms/step - loss: 8.7600e-04 - accuracy: 0.0000e+00 - val_loss: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 307/307 [==============================] - 2s 5ms/step - loss: 7.8701e-04 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 307/307 [==============================] - 2s 5ms/step - loss: 7.5978e-04 - accuracy: 0.0000e+00 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 307/307 [==============================] - 2s 5ms/step - loss: 6.6578e-04 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 307/307 [==============================] - 2s 5ms/step - loss: 5.9240e-04 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 307/307 [==============================] - 2s 5ms/step - loss: 5.6159e-04 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 307/307 [==============================] - 2s 6ms/step - loss: 4.7136e-04 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 307/307 [==============================] - 2s 6ms/step - loss: 4.5157e-04 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 307/307 [==============================] - 2s 5ms/step - loss: 4.1917e-04 - accuracy: 0.0000e+00 - val_loss: 0.0084 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 307/307 [==============================] - 2s 5ms/step - loss: 3.6954e-04 - accuracy: 0.0000e+00 - val_loss: 0.0087 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 307/307 [==============================] - 2s 5ms/step - loss: 3.5177e-04 - accuracy: 0.0000e+00 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 307/307 [==============================] - 2s 5ms/step - loss: 3.2305e-04 - accuracy: 0.0000e+00 - val_loss: 0.0091 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 307/307 [==============================] - 2s 5ms/step - loss: 3.1110e-04 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 203/307 [==================>...........] - ETA: 0s - loss: 3.0015e-04 - accuracy: 0.0000e+00
